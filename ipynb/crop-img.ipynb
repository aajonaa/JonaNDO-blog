# %%
from PIL import Image

# %%
img1 = Image.open('../images/Arnold-Schwarzenegger.jpeg')
img2 = Image.open('../images/Mike-Mentzer.jpeg')
img3 = Image.open('../images/Ronnie-Coleman.png')

# %%
w1, h1 = img1.size
w2, h2 = img2.size
w3, h3 = img3.size

# %%
w1, h1, w2, h2, w3, h3
# Out:
# (1024, 610, 1024, 610, 1024, 610)

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x610>

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x610>

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x610>

# %%
crop_img1 = img1.crop((0, 40, 1024, 650))

# %%
crop_img1
# Out:
# <PIL.Image.Image image mode=RGB size=1024x610>

# %%
crop_img3 = img3.crop((0, 0, 1024, 610))

# %%
crop_img3
# Out:
# <PIL.Image.Image image mode=RGBA size=1024x610>

# %%
crop_img1.size, img2.size, crop_img3.size,
# Out:
# ((1024, 610), (1024, 610), (1024, 610))

# %%
crop_img1.save('../images/Arnold-Schwarzenegger.jpeg')
crop_img3.save('../images/Ronnie-Coleman.png')

# %%
img4 = Image.open('../htmls/posts-passage/2publish-html-to-website/publish-html-to-website.jpeg')

# %%
img4.size
# Out:
# (1280, 719)

# %%
img4.size
# Out:
# (778, 719)

# %%
img4 = img4.crop((0, , 1020, 719))

# %%
img4.crop((20, 0, 1280, 720))
# Out:
# <PIL.Image.Image image mode=RGB size=778x699>

# %%
img4.save('../htmls/posts-passage/2publish-html-to-website/publish-html-to-website.jpeg')
